# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents=load_faq_data()
index=build_index(documents)

assistant=RAGBase(index,openai_client)

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'To get a certificate, you need to finish the course with a **live cohort** and **pass the Capstone project**.\n\nA certificate is **not available in self-paced mode** because you must also **peer-review 3 capstone submissions**, which can only be done while the course is running.'
